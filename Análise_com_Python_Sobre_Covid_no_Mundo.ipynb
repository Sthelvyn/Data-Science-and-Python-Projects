# %% [markdown]
# <a href="https://colab.research.google.com/github/Sthelvyn/Data-Science-and-Python-Projects/blob/main/An%C3%A1lise_com_Python_Sobre_Covid_no_Mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Moisés Sthelvyn**
# [Linkedin](https://www.linkedin.com/in/moises-sthelvyn/)
#
# ---

# %% [markdown]
# # Panorama do COVID-19 no Brasil e no Mundo!
#
#
# <center><img alt="Colaboratory logo" width="100%" src="https://github.com/Sthelvyn/template_portfolio/blob/6659d55cc29ccf963a12d4c4e20e941faaaa92e9/covid-19-virus-opas-848x477.png?raw=true"></center>
#
# A COVID - 19 é uma doença respiratória causada pelo coronavírus (SARS-CoV-2) que apareceu pela primeira vez em 17 de dezembro de 2019 na cidade de Wuhan, China. Sua transmissão ocorre através de gotículas presente no ar lançadas por pessoas infectadas por meio da tosse ou espirro.
#
# Os sintomas geralmente são tosse seca, dificuldade para respirar e febre, e em casos mais graves, que infelizmente não é raro, pode levar à morte.
# Diversas decisões foram tomadas para evitar a propagação da doença, como fechamento de locais de trabalho e a suspensão ou redução de atividades, até que surgisse uma vacina. Bom, a vacina chegou e com ela, a esperança.
#
#
# Com o objetivo de conscientizar do quão perigosa e devsastadora essa doença foi, irei trazer aqui uma análise exploratória completa dos casos pelo mundo.

# %% [markdown]
# ## Obtenção dos Dados
#
# Para esse estudo, busquei fontes seguras e atualizadas. O [Our World Data](https://ourworldindata.org/) é especializada em realizar pesquisas empíricas e dados analíticos sobre mudanças nas condições e qualidade de vida em todo o mundo.
#
# Dito isso, você pode acessar os dados usados nesse estudo clicando [aqui](https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data.csv).

# %% [markdown]
# ### Dicionário de Variáveis
#
# #Entendendo os dados
#
# Para fazê-lo entender da melhor forma possível, disponibilizo aqui um dicionário com todas as variáveis usadas no nosso dataframe.
#
# **Dicionário de variáveis**
# * `iso_code` - código de três letras de um país.
# * `continent` - continente.
# * `location` - localização geográfica.
# * `date` - data da observação
# * `total_cases` - total de casos confirmados da COVID-19.
# * `new_cases` - novos casos confirmados de COVID-19.
# * `new_cases_smoothed` - novos casos confirmados de COVID-19 (suavizado de 7 dias).
# * `total_deaths` - total de mortes por COVID-19.
# * `new_deaths` - novas mortes por COVID-19.
# * `new_deaths_smoothed` - novas mortes por COVID-17 (suavizado de 7 dias).
# * `total_cases_per_million` - total de casos confirmados de COVID-19 por 1.000.000 de pessoas.
# * `new_cases_per_million` - novos casos confirmados de COVID-19 por 1.000.000 de pessoas.
# * `new_cases_smoothed_per_million` - novos casos confirmados de COVID-19 (suavizado de 7 dias) por 1.000.000 de pessoas.
# * `total_deaths_per_million` - total de mortes de COVID-19 por 1.000.000 de pessoas.
# *`new_deaths_per_million` - novas mortes de COVID-19 por 1.000.000 de pessoas.
# *`new_deaths_smoothed_per_million` - novas mortes por COVID-19 (suavizado de 7 dias) por 1.000.000 de pessoas.
# * `reproduction_rate`	- taxa de recuperação da COVID-19 em tempo real.
# * `icu_patients` - número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia.
# * `icu_patients_per_million` - número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas.
# * `hosp_patients` - número de pacientes com COVID-19 em hospital em um determinado dia.
# * `hosp_patients_per_million` - número de pacientes com COVID-19 em hospital em um determinado dia por 1.000.000 de pessoas.
# * `weekly_icu_admissions` - número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana (data de notificação e 6 dias anteriores).
# * `weekly_icu_admissions_per_million`	- número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana (data de notificação e 6 dias anteriores) por 1.000.000 de pessoas.
# * `weekly_hosp_admissions` - número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana (data do relatório e 6 dias anteriores).
# * `weekly_hosp_admissions_per_million` - número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana (data do relatório e 6 dias anteriores) por 1.000.000 de pessoas.
# * `total_tests` - total de teste de COVID-19.
# * `new_tests` - total de novos testes por COVID-19.
# * `total_tests_per_thousand` - total de testes de COVID-19 por 1.000 pessoas.
# * `new_tests_per_thousand` - total de novos testes de COVID-19 por 1.000 pessoas.
# * `new_tests_smoothed` - total de novos testes de COVID-19 (suavizado de 7 dias).
# * `new_tests_smoothed_per_thousand` - total de novos testes de COVID-19 (suavizado de 7 dias) por 1.000 pessoas.
# * `positive_rate` - parcela de testes COVID-19 positivos, dada como uma média contínua de 7 dias (este é o inverso de tests_per_case).
# * `tests_per_case` - testes realizados por novo caso confirmado de COVID-19, dados como uma média contínua de 7 dias (este é o inverso de positive_rate).
# * `tests_units`	- unidades usadas pelo local para relatar seus dados de teste.
# * `total_vaccinations` - total de doses aplicadas da vacina da COVID-19.
# * `people_vaccinated` - total de pessoas vacinadas.
# * `people_fully_vaccinated` - total de pessoas que receberam todas as doses da vacina.
# * `total_boosters` - total das doses de reforçoda vacina.
# * `new_vaccinations` - novas doses de vacinadas aplicadas.
# * `new_vaccinations_smoothed` - novas doses de vacinas aplicadas (suavizada de 7 dias).
# * `total_vaccinations_per_hundred` - total de vacinas aplicadas por 100 pessoas.
# * `people_vaccinated_per_hundred` - total de pessoas que receberam ao menos uma dose da vacina por 100pessoas.
# * `people_fully_vaccinated_per_hundred` - total de pessoas que tomaram todas as doses da vacina por 100.
# * `total_boosters_per_hundred` - total de pessoas que tomaram a dose de reforço da vaxina por 100.
# * `new_vaccinations_smoothed_per_million` - novas doses de vacinas aplicadas (suavizado de 7 dias) por 1.000.000 de pessoas.
# * `new_people_vaccinated_smoothed` - número diário de pessoas que receberam a primeira dose da vacina (suavizado de 7 dias).
# * `new_people_vaccinated_smoothed_per_hundred` - número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias) por 100.
# * `stringency_index` - Índice de Rigidez de Resposta do Governo: medida composta com base em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, reescalonado para um valor de 0 a 100 (100 = resposta mais rigorosa).
# * `population` - população.
# * `population_density` - número de pessoas dividido por área de terra, medido em quilômetros quadrados.
# * `median_age` - idade mediana da população.
# * `aged_65_older` - população a partir dos 65 anos.
# * `aged_70_older` - população a partir dos 70 anos.
# * `gdp_per_capita` - produto interno bruto em paridade de poder de compra.
# * `extreme_poverty` - percentual da população que vive em extrema pobreza.
# * `cardiovasc_death_rate`	- taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas).
# * `diabetes_prevalence` - prevalência de diabetes (% da população de 20 a 79 anos) em 2017.
# * `female_smokers` - proporção de mulheres que fumam.
# * `male_smokers` - proporção de homens que fumam.
# * `handwashing_facilities` - percentagem da população com instalações básicas de lavagem das mãos nas instalações.
# * `hospital_beds_per_thousand` - camas hospitalares por 1.000 pessoas.
# * `life_expectancy` - expectativa de vida ao nascer em 2019.
# * `human_development_index` - índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano – uma vida longa e saudável, conhecimento e um padrão de vida decente.
# * `excess_mortality` - diferença percentual entre o número relatado de mortes semanais ou mensais em 2020-2021 e o número projetado de mortes para o mesmo período com base em anos anteriores.
# * `excess_mortality_cumulative` - diferença percentual entre o número acumulado de mortes desde 1 de janeiro de 2020 e as mortes cumulativas projetadas para o mesmo período com base em anos anteriores.
# * `excess_mortality_cumulative_absolute` - diferença cumulativa entre o número relatado de óbitos desde 1º de janeiro de 2020 e o número projetado de óbitos para o mesmo período com base em anos anteriores.
# * `excess_mortality_cumulative_per_million` - diferença cumulativa entre o número de mortes relatado desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base em anos anteriores, por 1.000.000 de pessoas.

# %% [markdown]
# ### Importando os dados do COVID-19

# %%
# !pip install wordcloud -q

# %%
# !pip install bar_chart_race -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.1 MB/s eta 0:00:00

# %%
# importando as bibliotecas necessárias

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import bar_chart_race as bcr


sns.set_style()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# importando o dataset COVID-19 para um DataFrame
data = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
df = pd.read_csv(data)

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Iremos analisar de forma completa os dados do COVID-19 no mundo.
# Para isso, vamos visualizar nosso *dataframe* para visualizar suas dimensões, identificar valores nulos e irrelevantes, e assim limpar o máximo esse conjunto de dados, trazendo assim, informações precisas e verídicas dos fatos. Vamos lá?

# %% [markdown]
# ### Análise Exploratória Inicial

# %%
#Visualizando informações gerais do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325411 entries, 0 to 325410
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    325411 non-null  object
#  1   continent                                   309967 non-null  object
#  2   location                                    325411 non-null  object
#  3   date                                        325411 non-null  object
#  4   total_cases                                 288176 non-null  float64
#  5   new_cases                                   316492 non-null  float64
#  6   new_cases_smoothed                          315233 non-null  float64
#  7   total_deaths                                267177 non-null  float64
#  8   new_deaths                                  316540 non-null  float64
# ...

# %%
#Visualizando as 5 primeiras entradas do dataframe
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#Verificando o tamanho do Dataframe
print("{} entradas".format(df.shape[0]))
print("{} atributos".format(df.shape[1]))
# Out:
# 325411 entradas
# 67 atributos

# %%
#Visualizando a distribuição
df.describe(include='all')
# Out:
#        iso_code continent location        date   total_cases     new_cases  \
# count    325411    309967   325411      325411  2.881760e+05  3.164920e+05
# unique      255         6      255        1289           NaN           NaN
# top         MEX    Africa   Mexico  2022-04-20           NaN           NaN
# freq       1289     73360     1289         255           NaN           NaN
# mean        NaN       NaN      NaN         NaN  6.127797e+06  1.028280e+04
# std         NaN       NaN      NaN         NaN  3.788953e+07  1.143154e+05
# min         NaN       NaN      NaN         NaN  1.000000e+00  0.000000e+00
# 25%         NaN       NaN      NaN         NaN  7.305000e+03  0.000000e+00
# 50%         NaN       NaN      NaN         NaN  6.392500e+04  4.000000e+00
# 75%         NaN       NaN      NaN         NaN  6.720390e+05  3.320000e+02
# max         NaN       NaN      NaN         NaN  7.679722e+08  8.401763e+06
#
# ...

# %% [markdown]
# ##Tratando as colunas Principais

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df_cvd = df.loc[:,['iso_code','continent', 'date', 'location', 'total_cases', 'new_cases','total_deaths', 'new_deaths', 'icu_patients', 'hosp_patients',
                     'total_tests', 'new_tests', 'positive_rate', 'tests_per_case', 'total_vaccinations','people_vaccinated',
                     'people_fully_vaccinated', 'total_boosters', 'new_vaccinations', 'population', 'median_age',
                     'aged_65_older','aged_70_older', 'female_smokers','male_smokers']].copy()

#Ver novo Dataframe
df_cvd.head()
# Out:
#   iso_code continent        date     location  total_cases  new_cases  \
# 0      AFG      Asia  2020-01-03  Afghanistan          NaN        0.0
# 1      AFG      Asia  2020-01-04  Afghanistan          NaN        0.0
# 2      AFG      Asia  2020-01-05  Afghanistan          NaN        0.0
# 3      AFG      Asia  2020-01-06  Afghanistan          NaN        0.0
# 4      AFG      Asia  2020-01-07  Afghanistan          NaN        0.0
#
#    total_deaths  new_deaths  icu_patients  hosp_patients  ...  \
# 0           NaN         0.0           NaN            NaN  ...
# 1           NaN         0.0           NaN            NaN  ...
# 2           NaN         0.0           NaN            NaN  ...
# 3           NaN         0.0           NaN            NaN  ...
# 4           NaN         0.0           NaN            NaN  ...
#
#    people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                NaN                      NaN             NaN
# ...

# %%
#Dento desse novo dataframe, vamos verificar os dados nulos
(((df_cvd.isnull().sum().sort_values(ascending=False))/ df_cvd.shape[0]) * 100).to_frame()
# Out:
#                                  0
# icu_patients             88.679854
# hosp_patients            88.408505
# total_boosters           86.106800
# new_vaccinations         80.588548
# people_fully_vaccinated  78.480445
# people_vaccinated        77.414716
# new_tests                76.828380
# total_vaccinations       76.414442
# total_tests              75.604082
# tests_per_case           71.006512
# positive_rate            70.521279
# male_smokers             42.651293
# female_smokers           41.860294
# aged_65_older            23.834474
# aged_70_older            21.861584
# median_age               21.070585
# total_deaths             17.895523
# total_cases              11.442453
# continent                 4.745998
# new_cases                 2.740842
# new_deaths                2.726091
# location                  0.000000
# date                      0.000000
# population                0.000000
# iso_code                  0.000000

# %% [markdown]
# Vou optar por excluir os atributo que constam mais 81% de valores nulos. São estes: *icu_patients*, *hosp_patients* e *total_boosters*.

# %%
#Excluir atributos informados
df_cvd.drop(['icu_patients', 'hosp_patients', 'total_boosters'], axis=1, inplace=True)

# %%
#Outros tratamentos úteis
df_cvd.drop(df_cvd.index[df_cvd.iso_code.str.contains("OWID")].values, inplace=True)

# %%
df_cvd.drop(['iso_code'], axis=1, inplace=True)

df_cvd.index = df_cvd.date

df_cvd.index = pd.to_datetime(df_cvd.index)

# %%
df_cvd.head()
# Out:
#            continent        date     location  total_cases  new_cases  \
# date
# 2020-01-03      Asia  2020-01-03  Afghanistan          NaN        0.0
# 2020-01-04      Asia  2020-01-04  Afghanistan          NaN        0.0
# 2020-01-05      Asia  2020-01-05  Afghanistan          NaN        0.0
# 2020-01-06      Asia  2020-01-06  Afghanistan          NaN        0.0
# 2020-01-07      Asia  2020-01-07  Afghanistan          NaN        0.0
#
#             total_deaths  new_deaths  total_tests  new_tests  positive_rate  \
# date
# 2020-01-03           NaN         0.0          NaN        NaN            NaN
# 2020-01-04           NaN         0.0          NaN        NaN            NaN
# 2020-01-05           NaN         0.0          NaN        NaN            NaN
# 2020-01-06           NaN         0.0          NaN        NaN            NaN
# 2020-01-07           NaN         0.0          NaN        NaN            NaN
#
#             ...  total_vaccinations  people_vaccinated  \
# ...

# %% [markdown]
# Para um melhor entendimento, vou renomear o termo do continente americano

# %%
df_cvd.replace(['North America', 'South America'], value="América", inplace=True)

# %% [markdown]
# ##Correlação entre as variáveis
#
# Iremos plotar um gráfico de correlação entre as variáveis usando o Heatmap.

# %%
corr = df_cvd.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))

fig, ax = plt.subplots(figsize=(12,12))

rc = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style='whitegrid', rc=rc)
sns.heatmap(corr, mask= mask, ax=ax, square=True, annot=True, vmin=-1, vmax=1, fmt='.2f')
ax.grid(False)

plt.tight_layout()

# %% [markdown]
# ##WORDCLOUD dos países com mais casos de Covid
#
# WordCloud é um recurso muito interessante para visualização de dados. Com poucas linhas de código, vamos mostrar com uma imagem, informações intuitivas sobre os casos.

# %%
#Trazer os países do dataset
pais = df_cvd.location.copy()

paragrafo = " ".join(pais)

stopwords = set(STOPWORDS)
stopwords.update(['Asia','Europe', 'Africa', 'North America', 'South America','Oceania','World', 'Cook Islands','High income','Low income',
                  'Lower middle income', 'North America','Upper middle income', 'middle income', 'middle','income','Lower','High','Low'])

#Criando a wordcloud
wordcloud = WordCloud(width=1200, height=600, stopwords=stopwords, background_color='black').generate(paragrafo)

fig, ax = plt.subplots(figsize=(12,10))

ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.tight_layout()

wordcloud.to_file("wordcloud_paises.png")

# %% [markdown]
# ##Continentes com mais casos de COVID-19 no mundo

# %%
df_cvd.groupby(['continent']).total_cases.sum().sort_values(ascending=False).to_frame()
# Out:
#             total_cases
# continent
# Europe     1.391539e+11
# Asia       1.359982e+11
# América    1.259576e+11
# Africa     9.547330e+09
# Oceania    5.905298e+09

# %%
porcentagem = (df_cvd.groupby(['continent']).total_cases.sum()/df_cvd.total_cases.sum() * 100).sort_values(ascending = False).to_dict()
porcentagem
# Out:
# {'Europe': 33.40530131033043,
#  'Asia': 32.64775145157563,
#  'América': 30.23738770081787,
#  'Africa': 2.2919330493765693,
#  'Oceania': 1.4176264878995075}

# %% [markdown]
# Plotando um gráfico com os continentes com mais casos

# %%
fig, ax = plt.subplots(nrows=2, figsize=(10,6))

x = df_cvd.groupby(['continent']).total_cases.sum().sort_values(ascending=False).index
y = df_cvd.groupby(['continent']).total_cases.sum().sort_values(ascending=False).values

sns.set_theme(style='dark', rc=rc)
ax[0].grid(False)
b = sns.barplot(x=x, y=y, ax=ax[0], palette='mako')
ax[0].set_title("Casos por Continente", fontsize=12)
ax[0].set_xlabel("Continentes", fontsize=12)
ax[0].set_ylabel('Casos', fontsize=12)

sns.set_theme(style='dark', rc=rc)
a = sns.barplot(x=list(porcentagem.keys()), y=list(porcentagem.values()), ax=ax[1], palette='mako', ci=False)
ax[1].grid(False)
ax[1].set_title("Casos por Continente em Porcentagem", fontsize=12)
ax[1].set_xlabel("Continentes", fontsize=12)
ax[1].set_ylabel('Porcentagem dos casos', fontsize=12)

plt.tight_layout()

# %% [markdown]
# Algo que muito se falou, foi da idade "de risco", em que pessoas com mais de 60 anos tinham mais riscos de sentirem sintomas graves. Vamos ver o que nosso dataframe nos mostra!

# %%
df_cvd.groupby(['continent']).median_age.mean().to_frame()
# Out:
#            median_age
# continent
# Africa      21.326884
# América     32.629842
# Asia        30.589799
# Europe      42.070000
# Oceania     27.607692

# %% [markdown]
# Pelo visto, a idade não é um fator (pelo menos não apenas ela) que está diretamente ligada à sintomas graves e risco de morte.

# %% [markdown]
# ##Total de mortes por continente

# %%
fig, ax = plt.subplots(figsize=(10,6))

tm = df_cvd.groupby(['continent']).total_deaths.sum().sort_values(ascending=False)[:10].to_dict()

sns.set_theme(style='dark', rc=rc)
vv = sns.barplot(x=list(tm.values()), y=list(tm.keys()), ax=ax, orient='h', palette='Blues_r')
ax.set_title("Mortes pelo Covid por Continente", fontsize=13)
ax.set_xlabel("Mortes", fontsize=13)
ax.set_ylabel("Países", fontsize=13)
ax.grid(False)

plt.tight_layout()

# %% [markdown]
# ##Continentes com mais pessoas vacinadas
#
# Podemos ver que as mortes foram consideráveis. Vamos agora observar o número de pessoas vacinadas em cada continente. Um passo importante para o controle da doença.

# %%
fig, ax = plt.subplots(figsize=(10,6))

# dados
pv = df_cvd.groupby(['continent']).people_vaccinated.sum().sort_values(ascending=False)[:10].to_dict()

# criar gráfico
sns.set_theme(style='whitegrid',rc=rc)
gcpv = sns.barplot(x=list(pv.keys()), y=list(pv.values()), ax=ax, orient='v', palette='Blues_r')
ax.set_title('Continentes com mais pessoas vacinadas contra a COVID-19', fontsize=14)
ax.set_xlabel('Continentes', fontsize=14)
ax.set_ylabel('Pessoas vacinadas', fontsize=14)
ax.grid(False)

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10,6))

# definindo dados
tmc = df_cvd.groupby(['continent']).new_vaccinations.mean().sort_values(ascending=False)[:10].to_dict()

# criando gráfico
sns.set_theme(style='whitegrid',rc=rc)
mmdc = sns.barplot(x=list(tmc.keys()), y=list(tmc.values()), ax=ax, orient='v', palette='Blues_r')
ax.set_title('Média de doses aplicadas',fontsize=14)
ax.set_xlabel('Continentes', fontsize=14)
ax.set_ylabel('Doses', fontsize=14)
ax.grid(False)

# colocar os valores no topo das barras
for i in mmdc.patches:
  ax.annotate('{:0.0f}'.format(i.get_height()), xy=(i.get_x()+i.get_width()/2, i.get_height()),
                 ha='center', color='black', xytext=(0,3), textcoords='offset points')

plt.tight_layout()

# %% [markdown]
# Abaixo vamos ver quando se iniciou as vacinas no mundo

# %%
print('Se iniciou em {}'.format(df_cvd.loc[df_cvd['people_vaccinated'] == df_cvd.people_vaccinated.min()].index[0]))
# Out:
# Se iniciou em 2021-02-22 00:00:00

# %% [markdown]
# ##Países com mais casos!
#
# Agora vamos filtrar um pouco mais os casos. Abaixo listo os países com mais casos de covid no mundo!

# %%
fig, ax = plt.subplots(figsize=(10,6))

pc = df_cvd.groupby(['location']).total_cases.sum().sort_values(ascending=False)[:10].to_dict()

sns.set_theme(style="whitegrid", rc=rc)
sns.barplot(x=list(pc.values()), y=list(pc.keys()), ax=ax, palette="Reds_r", orient='h')
ax.set_title("Países com mais casos", fontsize=13)
ax.set_xlabel("Casos", fontsize=13)
ax.set_ylabel("Países", fontsize=13)
ax.grid(False)

plt.tight_layout()

# %% [markdown]
# Como podemos perceber, os Estados Unidos foi o país com mais casos. Para aprofundar nesse caso, abaixo está o número de mortes **em um único dia** nesse país.

# %%
print('Os USA teve {:0.0f} casos em um único dia.'.format(df_cvd.loc[df_cvd['location'] == 'United States'].new_cases.max()))
# Out:
# Os USA teve 1265520 casos em um único dia.

# %% [markdown]
# Agora, dentro desses casos, vamos ver os países com mais **mortes** no mundo. Será que seguirá a mesma ordem?

# %%
df_cvd.groupby(['location']).total_deaths.sum().sort_values(ascending=False)[:10].to_frame()
# Out:
#                 total_deaths
# location
# United States    851064377.0
# Brazil           574320530.0
# India            430836106.0
# Mexico           292257667.0
# Russia           275115346.0
# Peru             197951305.0
# United Kingdom   188126132.0
# Italy            151527866.0
# France           132153080.0
# Germany          122324986.0

# %% [markdown]
# O Brasil, de terceiro lugar, pulou para segundo. E uma surpresa foi o *México*, que não está entre os 10 países com mais casos, mas está entre os 10 com mais mortes!

# %%
fig, ax = plt.subplots(figsize=(10,7))

# definir atributos
data = df_cvd.groupby(['location']).total_deaths.sum().sort_values(ascending=False)[:10].to_dict()

# plotar gráfico com total de mortes
sns.set_theme(style='whitegrid', rc=rc)
sns.barplot(x = list(data.values()), y = list(data.keys()), ax=ax, orient='h', palette='Reds_r')
ax.grid(False)
ax.set_xlabel('Mortes', fontsize=14)
ax.set_ylabel('Países', fontsize=14)
ax.set_title('Países com mais mortes por Covid', fontsize=14)

plt.tight_layout()

# %% [markdown]
# ##Média de mortes diárias por covid por país

# %%
# construir gráfico com a média de mortes diárias
fig, ax = plt.subplots(figsize=(10,7))

# definindo dados
data2 = df_cvd.groupby(['location']).new_deaths.mean().sort_values(ascending=False)[:10].to_dict()

# plotar gráfico com a média de mortes por dia
sns.set_theme(style='whitegrid', rc=rc)
c = sns.barplot(x = list(data2.keys()), y = list(data2.values()), ax=ax, orient='v', palette='Greys_r')
ax.set_xlabel('Mortes', fontsize=14)
ax.set_ylabel('Países', fontsize=14)
ax.set_title('Média de mortes diárias por COVID por país', fontsize=14)
ax.grid(False)

plt.tight_layout()

# %% [markdown]
# ##COVID NO BRASIL
#
# Agora, afunilando ainda mais nosso estudo, vamos ver os dados de covid em relação ao nosso país!

# %% [markdown]
# Vamos plotar um gráfico com as mortes por covid no Brasil, e logo abaixo, um gráfico com as pessoas vacinadas. Após isso, vamos comparar.

# %%
datas = df_cvd.iloc[2:].copy()

bra = datas.loc[datas['location'] == 'Brazil']

fig, ax = plt.subplots(nrows=2, figsize=(10, 7))

sns.lineplot(x=bra.index, y=bra.new_deaths.rolling(window=7, min_periods=5, center=True).mean(), linewidth=2.0, color='g', ax=ax[0])
ax[0].set_title('Média de mortes diárias por covid no BRASIL', fontsize=14)
ax[0].set_ylabel('Mortes', fontsize=14)
ax[0].set_xlabel('Data', fontsize=14)
ax[0].grid(False)

sns.lineplot(x=bra.index, y=bra.people_vaccinated, linewidth=2.0, linestyle='--', color='yellow', ax=ax[1])
ax[1].set_title('Pessoas vacinadas no Brasil', fontsize=14)
ax[1].set_ylabel('Pessoas vacinadas', fontsize=14)
ax[1].set_xlabel('Data', fontsize=14)
ax[1].grid(False)

plt.tight_layout()

# %% [markdown]
# Destrinchando o nosso dataframe, podemos afirmar, em relação ao Brasil, que:

# %%
# ver quando o Brasil começou a vacinar sua população
print('Em {} começou o período de vacinação contra a COVID-19 no Brasil.\n'.format(bra.loc[bra['total_vaccinations'] == bra.total_vaccinations.min()].index[0]))

# ver quando 1/3 da população brasileira estava vacinada
print('Em {} 1/3 da população estava vacinada no Brasil.\n'.format(bra.loc[bra['people_vaccinated'] >= bra.population / 3].index[0]))

# comparar média diária de mortes antes e depois de 1/3 estar vacinado
print('Antes da vacina: {:0.0f} mortes diárias por COVID-19.'.format(bra[:'2021-06-28'].new_deaths.mean()))
print('Depois da vacina: {:0.0f} mortes diárias por COVID-19.\n'.format(bra['2021-06-28':].new_deaths.mean()))

# ver pico de mortes em um dia
print('{:0.0f} foi o pico de mortes diárias por COVID-19 no Brasil.'.format(bra.new_deaths.max()))
# Out:
# Em 2021-01-17 00:00:00 começou o período de vacinação contra a COVID-19 no Brasil.
#
# Em 2021-06-28 00:00:00 1/3 da população estava vacinada no Brasil.
#
# Antes da vacina: 944 mortes diárias por COVID-19.
# Depois da vacina: 260 mortes diárias por COVID-19.
#
# 4249 foi o pico de mortes diárias por COVID-19 no Brasil.

# %% [markdown]
# ## Conclusão
#
# Após esse mergulho profundo nos dados, conseguimos extrair informações valiosíssimas em relação ao Covid-19 no Brasil e em todo o mundo. Dentre elas:
# - *A América foi o continente com mais mortes pelo vírus*;
# - *A Ásia foi o continente que maiss vacinou sua população;
# - *A média de idades afetadas pelo vírus foram na África, América, Ásia, Europa e Oceania foram: 21, 32, 30, 42 e 27 anos, respectivamente;*
# - *Estados Unidos, Brasil e Índia foram os países com mais mortes por covid no mundo;*
# - *Após a vacina, o número de mortes diárias diminuiu mais de 70%;*
# - *O mais importante: Quanto mais pessoas eram vacinadas, menor era a taxa de mortalidade pelo vírus!*
#
# Encerro, portanto, essa análise, salientando o objetivo dela. Esse estudo se baseou em dados públicos, a fim de entender mais sobre esse fato histórico que marcou nossa história para sempre. Lembrando, também, que os dados se atualizam a todo instante, e podemo conter alterações, dependendo de quando você está lendo esse notebook. Essa análise foi realizada dia 13/07/2023.
#
# Espero ter sido claro ao expor as informações dentro dos dados. Estou aprendendo ainda, e ansioso pelo que me espera à frente. Agradeço que tenh chegado até aqui.
#
# Acesse meu portfólio clicando [aqui](https://github.com/Sthelvyn)
